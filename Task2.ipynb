# %% [markdown]
# <a href="https://colab.research.google.com/github/jeeva477/DL_Skill_Tracker/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

# Xavier
m1 = nn.Linear(128, 128)
nn.init.xavier_uniform_(m1.weight)

# He
m2 = nn.Linear(128, 128)
nn.init.kaiming_uniform_(m2.weight, nonlinearity="relu")

# Input
x = torch.randn(64, 128)

# Forward pass
a1 = torch.relu(m1(x))
a2 = torch.relu(m2(x))

print("Xavier activation variance:", a1.var().item())
print("He activation variance:", a2.var().item())
# Out:
# Xavier activation variance: 0.330197274684906
# He activation variance: 0.6567868590354919
