# %% [markdown]
# # Task 4: Custom Gradient Descent Optimizers from Scratch
# Implementing SGD with Momentum, RMSprop, and Adam using PyTorch tensor math from first principles.

# %%
import torch
import matplotlib.pyplot as plt
from optimizers_from_scratch import compare_optimizers
print('PyTorch Optimizers environment loaded.')
# Out:
# PyTorch Optimizers environment loaded.

# %%
# Run optimization comparison on non-linear dataset
compare_optimizers()
print('Training completed. Convergence curves saved.')
# Out:
# Training completed. Convergence curves saved.

# %%
# Display convergence plot
img = plt.imread('optimizer_convergence.png')
plt.figure(figsize=(8, 4))
plt.imshow(img)
plt.axis('off')
plt.show()
