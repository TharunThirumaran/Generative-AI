# %% [markdown]
# # Task 6: Bidirectional Long Short-Term Memory (BiLSTM) Cell Mechanics
# Implementing gated recurrent cell equations and bidirectional temporal sequence tracking from scratch.

# %%
import torch
from bilstm_scratch import BiLSTMScratch
print('PyTorch BiLSTM module ready.')
# Out:
# PyTorch BiLSTM module ready.

# %%
# Sequence Input: Batch=4, Sequence Length=10, Feature Dim=16
X = torch.randn(4, 10, 16)
bilstm = BiLSTMScratch(input_dim=16, hidden_dim=32)
out = bilstm.forward(X)
print(f'Input Sequence Shape:  {X.shape}')
print(f'BiLSTM Output Shape: {out.shape} (Forward 32 + Backward 32 = 64 features)')
# Out:
# Input Sequence Shape:  torch.Size([4, 10, 16])
# BiLSTM Output Shape: torch.Size([4, 10, 64]) (Forward 32 + Backward 32 = 64 features)
