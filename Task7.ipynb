# %% [markdown]
# # Task 7: ResNet-50 Residual Bottleneck Block & Profiler
# Constructing deep residual bottleneck block and profiling memory & compute using PyTorch Profiler.

# %%
import torch
from resnet_bottleneck_profiler import ResNetBottleneck, run_profiler
print('ResNet Bottleneck setup initialized.')
# Out:
# ResNet Bottleneck setup initialized.

# %%
# Run bottleneck block forward pass
x = torch.randn(4, 64, 56, 56)
block = ResNetBottleneck(in_channels=64, bottleneck_channels=64, out_channels=256)
out = block(x)
print(f'Input shape: {x.shape} -> Output shape: {out.shape}')
# Out:
# Input shape: torch.Size([4, 64, 56, 56]) -> Output shape: torch.Size([4, 256, 56, 56])

# %%
# Profile execution performance
run_profiler()
# Out:
# --------------------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                             Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg    # of Calls
# --------------------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                  model_inference        19.65%      18.921ms       100.00%      96.306ms      96.306ms             1
#                     aten::conv2d         0.08%      76.300us        49.18%      47.364ms      11.841ms             4
#                aten::convolution         0.23%     222.400us        49.10%      47.287ms      11.822ms             4
#               aten::_convolution         0.11%     109.300us        48.87%      47.065ms      11.766ms             4
#         aten::mkldnn_convolution        48.29%      46.505ms        48.76%      46.956ms      11.739ms             4
# ...
