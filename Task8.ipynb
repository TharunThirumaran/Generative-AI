# %% [markdown]
# # Task 8: Semantic Segmentation Pipeline & Custom Soft Dice Loss
# Building U-Net architecture with custom Soft Dice + BCE composite loss.

# %%
import torch
import matplotlib.pyplot as plt
from unet_dice_segmentation import SimpleUNet, SoftDiceBCELoss, train_and_plot
print('UNet segmentation module loaded.')
# Out:
# UNet segmentation module loaded.

# %%
# Run training loop
train_and_plot()
# Out:
# UNet segmentation training completed. Final Loss: 1.1707

# %%
# Display Precision-Recall boundary curve
img = plt.imread('segmentation_pr_curve.png')
plt.figure(figsize=(6, 3))
plt.imshow(img)
plt.axis('off')
plt.show()
